# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import aux
color_inp="#36454F"
color_ee = "#A52A2A"
color_ei = (242/256, 140/256, 40/256)
color_ie = (8/256, 143/256, 143/256)
color_ii = (47/256, 85/256, 151/256)

# %% [markdown]
# # 1/ Simulate one spiking neural network

# %% [markdown]
# Call an auryn (C++) simulation with the parameters defined here.
# Choose one task to run
# Make sure that the corresponding auryn file is compiled before running the cells below
# The C++ simulation will write .ras and .syn files in a directory (by default "../Innerloops/cpp_innerloops/sim_workdir/")

# %% [markdown]
# ## Stability task

# %% [markdown]
# ### Stability with I-to-E plasticity, small polynomial rule (bg_TIF_IE_6pPol)

# %%
# Simulation parameters
t_max = 120
simulator_params = dict([("auryn_sim_dir", "../../Innerloops/cpp_innerloops/"),
                         ("name", "sim_innerloop_bg_TIF_IE_6pPol"),
                         ("ID", 0),
                         ("NE", 8000),
                         ("NI", 2000),
                         ("wee", 0.1),
                         ("wei", 0.1),
                         ("wie", 1),
                         ("wii", 1),
                         ("eta", 0.01),
                         ("rule", {'tau_pre': 0.05434836547,
                                   'tau_post': 0.09752295722,
                                   'alpha': -1.41113062,
                                   'beta': 0.01545933,
                                   'gamma': 0.71641236,
                                   'kappa': 1.0808928 }),
                         ("sparseness", 0.02),
                         ("wmax", 5),
                         ("lns", 0.01),
                         ("ls", t_max),
                         ("target", 10),
                         ("N_inputs", 5000),
                         ("sparseness_poisson", 0.05),
                         ("w_poisson", 0.1),
                         ("poisson_rate", 5),
                         ("min_rate_checker", 0.1),
                         ("max_rate_checker", 100),
                         ("tau_checker", 1),
                         ("workdir", "../Innerloops/cpp_innerloops/sim_workdir/")])

## Simulate the network in C++
print(aux.compile_and_run_auryn_net(simulator_params))

# %% [markdown]
# ### Stability with I-to-E plasticity, big polynomial rule (bg_CVAIF_IE_T4wvceciPol)

# %%
# Simulation parameters
t_max = 120

Theta_2307130029 = np.array([-0.02364482,  0.00336024,  0.00543746, -0.00320788, -0.00296896,
        0.01579432,  0.0023953 , -0.00043673,  0.00727372, -0.00740728,
        0.01127809, -0.00129406,  0.01142924, -0.00701361, -0.00217044,
       -0.00826377,  0.00350835, -0.01166947,  0.0056595 ,  0.00019811,
        0.00819701])

simulator_params = dict([("auryn_sim_dir", "../Innerloops/cpp_innerloops/"),
                         ("name", "sim_innerloop_bg_CVAIF_IE_T4wvceciPol"),
                         ("ID", 0),
                         ("NE", 4096),
                         ("NI", 1024),
                         ("wee", 0.1),
                         ("wei", 0.1),
                         ("wie", 1),
                         ("wii", 1),
                         ("rule", Theta_2307130029),
                         ("sparseness", 0.1),
                         ("wmax", 10), #10
                         ("lns", 1),
                         ("ls", t_max-1),
                         ("target", 10),
                         ("N_inputs", 5000),
                         ("sparseness_poisson", 0.05),
                         ("w_poisson", 0.1),
                         ("poisson_rate", 5),
                         ("min_rate_checker", 0.1),
                         ("max_rate_checker", 100),
                         ("tau_checker", 1),
                         ("workdir", "../Innerloops/cpp_innerloops/sim_workdir/")])

# ## Simulate the network in C++
print(aux.compile_and_run_auryn_net(simulator_params))

# %% [markdown]
# ### Stability with I-to-E plasticity, MLP rule (bg_CVAIF_IE_T4wvceciMLP)

# %%
t_max = 120
simulator_params = dict([("lns", 0.1),
                         ("ls", t_max),
                         ("name", "sim_innerloop_bg_CVAIF_IE_T4wvceciMLP"),
                         ("auryn_sim_dir", "../Innerloops/cpp_innerloops/"),
                         ("workdir", "../Innerloops/cpp_innerloops/sim_workdir/"),
                         ("NE", 4096),
                         ("NI", 1024),
                         ("tau_ampa", 5e-3),
                         ("tau_gaba", 10e-3),
                         ("tau_nmda", 100e-3),
                         ("ampa_nmda_ratio", 0.3),
                         ("tau_vtrace", 0.1),
                         ("tau_cexc", 0.01),
                         ("tau_cinh", 0.1),
                         ("nh1", 50),
                         ("nh2", 4),
                         ("wee", 0.1),
                         ("wei", 0.1),
                         ("wie", 1),
                         ("wii", 1),
                         ("wmax", 10),
                         ("sparseness", 0.1),
                         ("N_inputs", 5000),
                         ("sparseness_poisson", 0.05),
                         ("w_poisson", 0.075),
                         ("poisson_rate", 5),
                         ("min_rate_checker",0.1),
                         ("max_rate_checker",100),
                         ("eta", 0.01),
                         ("target", 10),
                         ("tau_checker", 1),
                         ("rule", [0.31234013,0.62988,-1.34159424,-0.80779383,-0.5324167,-1.79743016,
                                   0.9813101, 0.25854838, 0.02447846,0.41436559,0.34331479]),
                         ("rule_cst_part", [ 1.00000000e-02,  1.00000000e-01,  1.00000000e-02,  1.00000000e-01,
        3.30212086e-01,  1.45547777e-01,  2.97209859e-01,  2.34276906e-01,
        3.98491442e-01,  2.82270640e-01, -3.99559826e-01,  1.21451199e-01,
        1.34779483e-01,  1.94424093e-01,  3.05792749e-01, -3.01998734e-01,
        2.32351154e-01,  3.54063362e-01, -3.59196663e-01, -1.45204052e-01,
        1.08948164e-01, -2.41740286e-01, -7.34276846e-02, -1.41777351e-01,
       -2.12670177e-01, -1.13920033e-01,  3.39862287e-01, -3.26696724e-01,
        3.70301872e-01,  2.16886640e-01,  4.93309051e-02,  3.53827477e-01,
       -2.30962783e-01,  3.01217467e-01,  1.89402103e-01,  3.31849217e-01,
       -3.25362474e-01, -1.53380543e-01,  3.53093624e-01,  2.89691687e-01,
       -6.64493218e-02, -1.81519210e-01,  4.06983703e-01,  5.84547967e-02,
        8.43532309e-02,  1.18587978e-01,  1.44785807e-01, -3.30908805e-01,
        1.64875388e-01, -3.58747125e-01, -1.21657453e-01, -1.05664745e-01,
       -1.67186692e-01,  3.52372862e-02,  1.66229501e-01, -2.63035208e-01,
       -3.98169190e-01, -3.54669660e-01, -8.88630524e-02, -3.66358101e-01,
        1.69092238e-01,  2.27268711e-01,  3.51177305e-01,  3.04931164e-01,
       -7.05165863e-02,  5.37816733e-02, -5.60638420e-02, -5.31119434e-03,
        4.54411507e-02, -9.56128240e-02,  8.34553689e-02,  1.04315884e-01,
        1.01708256e-01, -1.10040978e-01,  5.93886040e-02,  2.87524126e-02,
        2.33619157e-02, -7.74583891e-02, -1.08906031e-01,  1.30516998e-02,
        6.02029674e-02, -1.27308100e-01, -1.14061765e-01,  1.24614477e-01])
                        ])

print(aux.compile_and_run_auryn_net(simulator_params))

# %% [markdown]
# ## Familiarity detection task

# %% [markdown]
# ### Familiarity detection with I-to-E plasticity, small polynomial rule (FamDet_Lbasic_TIF_IE_6pPol)

# %%
# Simulation parameters
simulator_params = dict([("auryn_sim_dir", "../Innerloops/cpp_innerloops/"),
                         ("name", "sim_innerloop_FamDet_Lbasic_TIF_IE_6pPol"),
                         ("ID", 0),
                         ("NE", 8000), #8000
                         ("NI", 2000), #2000
                         ("wee", 0.03), #0.03 (0.3nS = 0.03 in units of gleak)
                         ("wei", 0.03), #0.03
                         ("wie", 0.3), #0.3
                         ("wii", 0.3), #0.3
                         ("eta", 0.01), #0.01
                        ("rule", {'tau_pre': 0.1, #No plasticity for control
                                   'tau_post': 0.1,
                                   'alpha': 0,
                                   'beta': 0,
                                   'gamma': 0,
                                   'kappa': 0}),
                         ("sparseness", 0.02),#0.02
                         ("wmax", 3), #2
                         ("l_train", 50),
                         ("l_break1", 5), #3
                         ("l_score", 5), #2
                         ("l_break2", 5), #3
                         ("rate_cut_fam", 20), #20
                         ("rate_cut_nov", 10), #10
                         ("N_inputs", 5000), #5000
                         ("w_poisson", 0.1), #0.1
                         ("bg_input_rate", 4), # between 1 and 5
                         ("N_active_input", 500),
                         ("active_input_rate", 18), # added to bg_input_rate for active stimulus
                         ("N_patterns", 1),
                         ("radius", 8),
                         ("tau_checker_pop", 1),
                         ("ontime_train", 2),
                         ("offtime_train", 0.1),
                         ("ontime_test", 100),
                         ("offtime_test", 100),
                         ("min_rate_checker", 0.1),
                         ("max_rate_checker", 200),
                         ("workdir", "../Innerloops/cpp_innerloops/sim_workdir/")])

## Simulate the network in C++
print(aux.compile_and_run_auryn_net(simulator_params))

# %% [markdown]
# ### Familiarity detection with E-to-E and I-to-E plasticity, small polynomial rule (FamDet_Lbasic_TIF_EEIE_6pPol)

# %%
# Simulation parameters
simulator_params = dict([("auryn_sim_dir", "../Innerloops/cpp_innerloops/"),
                         ("name", "sim_innerloop_FamDet_Lbasic_TIF_EEIE_6pPol"),
                         ("ID", 0),
                         ("NE", 8000),
                         ("NI", 2000),
                         ("wee", 0.03), #(0.3nS = 0.03 in units of gleak)
                         ("wei", 0.03),
                         ("wie", 0.3),
                         ("wii", 0.3),
                         ("eta", 0.01),
                         #2310070017_FamDet_Lbasic_TIF_EEIE_6pPol_CMA
                         ("ruleEE", {'tau_pre': np.exp(-4.60250164),  
                                   'tau_post': np.exp(-4.80154415),
                                   'alpha': 0.05259926,
                                   'beta': -0.03645123,
                                   'gamma': 0.10723248,
                                   'kappa': -0.1922089}),
                         ("ruleIE", {'tau_pre': np.exp(-4.64030669),
                                   'tau_post': np.exp(-4.63020023),
                                   'alpha': -0.10807499,
                                   'beta': 0.13765434,
                                   'gamma': -0.04375405,
                                   'kappa': -0.25140329}),
                         ("sparseness", 0.02),
                         ("wmaxee", 0.3),
                         ("wmaxie", 3),
                         ("l_train", 50),
                         ("l_break1", 5),
                         ("l_score", 5),
                         ("l_break2", 5),
                         ("rate_cut_fam", 15),
                         ("rate_cut_nov", 5),
                         ("N_inputs", 5000),
                         ("w_poisson", 0.1),
                         ("bg_input_rate", 3), # between 1 and 5
                         ("N_active_input", 500),
                         ("active_input_rate", 18), # added to bg_input_rate for active stimulus
                         ("N_patterns", 1),
                         ("radius", 8),
                         ("tau_checker_pop", 1),
                         ("ontime_train", 2),
                         ("offtime_train", 0.1),
                         ("ontime_test", 100),
                         ("offtime_test", 100),
                         ("min_rate_checker", 0.1),
                         ("max_rate_checker", 200),
                         ("workdir", "../Innerloops/cpp_innerloops/sim_workdir/")])

## Simulate the network in C++
print(aux.compile_and_run_auryn_net(simulator_params))
# Out:
# ../Innerloops/cpp_innerloops/sim_innerloop_FamDet_Lbasic_TIF_EEIE_6pPol --ID 0 --NE 8000 --NI 2000 --wee 0.03 --wei 0.03 --wie 0.3 --wii 0.3 --eta 0.01 --ruleEE a0.010026721097262315a0.008217048891567325a0.05259926a-0.03645123a0.10723248a-0.1922089a --ruleIE a0.009654736162401468a0.00975280610245895a-0.10807499a0.13765434a-0.04375405a-0.25140329a --wmaxee 0.3 --wmaxie 3 --sparseness 0.02 --l_train 50 --l_break1 5 --l_score 5 --l_break2 5 --rate_cut_fam 15 --rate_cut_nov 5 --N_inputs 5000 --w_poisson 0.1 --bg_input_rate 3 --active_input_rate 18 --N_active_input 500 --N_patterns 1 --radius 8 --tau_checker_pop 1 --ontime_train 2 --offtime_train 0.1 --ontime_test 100 --offtime_test 100 --min_rate_checker 0.1 --max_rate_checker 200 --workdir ../Innerloops/cpp_innerloops/sim_workdir/
# COMPILATION:
#
#  Input:
#
# cd ../Innerloops/cpp_innerloops/ && make sim_innerloop_FamDet_Lbasic_TIF_EEIE_6pPol
#
#  Return:
#
# ...

# %% [markdown]
# # 2/ Plot results

# %% [markdown]
# ### Familiarity detection with E-to-E and I-to-E plasticity, small polynomial rule (FamDet_Lbasic_TIF_EEIE_6pPol)

# %%
sts_inp = aux.get_spiketimes_auryn(simulator_params["workdir"] + "input.e.0.ras", simulator_params["N_inputs"])
sts_e = aux.get_spiketimes_auryn(simulator_params["workdir"] + "out.e.0.ras", simulator_params["NE"])
sts_i = aux.get_spiketimes_auryn(simulator_params["workdir"] + "out.i.0.ras", simulator_params["NI"])
w_dict_ee = aux.get_weights_auryn(simulator_params["workdir"] + "con_ee.0.syn", bin_size=0.1)
w_dict_ie = aux.get_weights_auryn(simulator_params["workdir"] + "con_ie.0.syn", bin_size=0.1)

# %%
aux.plot_simulation_2x6pPol_FamDet(sts_inp=sts_inp,
        sts_e=sts_e,
        sts_i=sts_i,
        w1=w_dict_ee,
        w2=w_dict_ie,
        n_exc=5000, n_inh=2000, n_input=5000,
        t_start=0,
        t_stop=70,
        axwidth=1.5,
        linewidth=1.5,
        fontsize=10,
        figsize=(2, 3),
        xlim=[45, 70],
        x_ticks=[45, 70],
        x_label="t (s)",
        color_inp=color_inp, color_exc=color_ee, color_inh=color_ii, color_w1=color_ee, color_w2=color_ie,
        
        ms_raster_inp=0.01,
        ms_raster_e=0.005,
        ms_raster_i=0.005,
        n_to_plot_raster=1000,
        
        y_lim_pop_rate=[0, 60],
        y_ticks_pop_rate=[0,30,60],
        window_pop_rate=0.2,
                                        
        y_label_w1 = r'$w^{E\to E}_{ij}$',
        y_label_w2 = r'$w^{I\to E}_{ij}$',                            
        y_lim_w1=[0,0.3],
        y_ticks_w1=[0,0.3],
        y_ticklabels_w1=None,
        y_lim_w2=[0,3],
        y_ticks_w2=[0,3],
        y_ticklabels_w2=None,
        linewidth_weights=0.8, 
        n_to_plot_weights=20,
        alpha_w=0.3)
# Out:
# /Users/bcfx/Documents/SpikES/Analysis/aux.py:3328: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax5.set_xticklabels(["" for i in range(len(x_ticks))])

# %% [markdown]
# ### Stability with I-to-E plasticity, small polynomial rule (bg_TIF_IE_6pPol)

# %%
sts_inp = aux.get_spiketimes_auryn(simulator_params["workdir"] + "input.e.0.ras", simulator_params["N_inputs"])
sts_e = aux.get_spiketimes_auryn(simulator_params["workdir"] + "out.e.0.ras", simulator_params["NE"])
sts_i = aux.get_spiketimes_auryn(simulator_params["workdir"] + "out.i.0.ras", simulator_params["NI"])
w_dict_ie = aux.get_weights_auryn(simulator_params["workdir"] + "con_ie.0.syn", bin_size=0.1)

# %%
aux.plot_simulation_6pPol_bg(sts_e=sts_e,
        sts_i=sts_i,
        wie=w_dict_ie ,
        n_exc=8000, n_inh=2000, n_input=5000,
        t_start=0,
        t_stop=t_max,
        axwidth=1.5,
        linewidth=1.5,
        fontsize=10,
        figsize=(2, 2.2),
        xlim=[t_max-10, t_max-5],
        x_ticks=[t_max-10, t_max-5],
        x_label="t (s)",
        color_inp=color_inp, color_exc=color_ee, color_inh=color_ii, color_ie=color_ie,
        
        ms_raster=0.2,                      
        n_to_plot_raster=100,
        
        y_lim_pop_rate=[5, 15],
        y_ticks_pop_rate=[5,10,15],
        window_pop_rate=0.2,
                                      
        y_lim_wi=[0,2.5],
        y_ticks_wi=[0,2],
        y_ticklabels_wi=None,
        linewidth_weights=0.8, 
        n_to_plot_weights=20,
        alpha_w=0.4)
